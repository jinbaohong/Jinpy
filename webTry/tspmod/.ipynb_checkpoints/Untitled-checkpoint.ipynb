# %%
import pandas as pd

# %%
x = pd.read_csv('showTable/tmp/tspmod2015.csv')

# %%
country = 'India'

x.loc[(x['EXHIBITION_COUNTRY'].isin([country])) &
      (x['svd'] > 0.5)].to_dict('records')
# Out:
# [{'CONTACT_EMAIL': 'indextb@indextb.com',
#   'EXHIBITION_COUNTRY': 'India',
#   'EXHIBITION_INDUSTRY': 'MedicalCare,Health/HealthCare(Equipment,Products&Services);FundamentalIndustries/Mining,Energy;Building,Construction/Building&Construction,RealEstate;Hobby,Education/Tourism&Travel(Goods,Facilities&Services);Environment/EnvironmentalProtection,WasteDisposal,Recycling;Agriculture,Forestry,FisheryandFood/Agriculture,Forestry,FisheryProducts',
#   'EXHIBITION_LOCATION': 'Mahatma Mandir',
#   'EXHIBITION_NAME': '7th Vibrant Gujarat Summit(VG)',
#   'EXHIBITS': 'AUTOMOBILES, BANKING & FINANCE,OIL GAS RENEWABLE ENERGY & PACKING, CONSTRUCTION & REAL ESTATE, HEAVY ENGINEERING,',
#   'FREQUENCY': 'Biennial',
#   'svd': 0.515165377},
#  {'CONTACT_EMAIL': 'ire2015@indiarubberexpo.in.',
#   'EXHIBITION_COUNTRY': 'India',
# ...

# %%
x.loc[(x['EXHIBITION_COUNTRY'].isin([country])) &
      (x['svd'] > 0.5)].fillna('null').to_dict('records')
# Out:
# [{'CONTACT_EMAIL': 'indextb@indextb.com',
#   'EXHIBITION_COUNTRY': 'India',
#   'EXHIBITION_INDUSTRY': 'MedicalCare,Health/HealthCare(Equipment,Products&Services);FundamentalIndustries/Mining,Energy;Building,Construction/Building&Construction,RealEstate;Hobby,Education/Tourism&Travel(Goods,Facilities&Services);Environment/EnvironmentalProtection,WasteDisposal,Recycling;Agriculture,Forestry,FisheryandFood/Agriculture,Forestry,FisheryProducts',
#   'EXHIBITION_LOCATION': 'Mahatma Mandir',
#   'EXHIBITION_NAME': '7th Vibrant Gujarat Summit(VG)',
#   'EXHIBITS': 'AUTOMOBILES, BANKING & FINANCE,OIL GAS RENEWABLE ENERGY & PACKING, CONSTRUCTION & REAL ESTATE, HEAVY ENGINEERING,',
#   'FREQUENCY': 'Biennial',
#   'svd': 0.515165377},
#  {'CONTACT_EMAIL': 'ire2015@indiarubberexpo.in.',
#   'EXHIBITION_COUNTRY': 'India',
# ...
